# %%
# Calculcus - Differentiation
# https://www.youtube.com/watch?v=BcOPKQAZcn0
# Differentiating gives the gradient of a graph

import sympy
x,t = symbols('x, t')
#f = exp(x)*cos(x)
#derivative_f = f.diff(x)
#derivative_f

# %%
f = 2*x**3-5*x**2+4*x+7 # Example 1 (a) - Page 110 - Ch2 Calculus: A Complete Course
derivative_E1A = f.diff(x)
derivative_E1A
# Out:
# 6*x**2 - 10*x + 4

# %%
from sympy import symbols
from sympy.plotting import plot

p1 = plot(derivative_E1A, title="Example 1 (a)")

# %%
f = 5*sympy.sqrt(x)+3/x - 18 # Example 1 (b)
derivative_E1B = f.diff(x)
derivative_E1B
# Out:
# -3/x**2 + 5/(2*sqrt(x))

# %%
from sympy import symbols
from sympy.plotting import plot

p1 = plot(derivative_E1B, title="Example 1 (b)")

# %%
f = Rational(1 , 7)*t**4-3*t**Rational(7, 3) # Example 1 (c)
derivative_E1C = f.diff(t)
derivative_E1C
# Out:
# -7*t**(4/3) + 4*t**3/7

# %%
from sympy import symbols
from sympy.plotting import plot

p1 = plot(derivative_E1C, title="Example 1 (c)")
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
