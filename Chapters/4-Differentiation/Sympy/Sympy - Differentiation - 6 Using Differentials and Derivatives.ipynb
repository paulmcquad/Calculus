# %%
# Calculcus - Sympy - Differentiation - 6 Using Differentials and Derivatives 
# Page 131 - Ch2 Calculus: A Complete Course
#
# Differentiating gives the gradient of a graph
from sympy import *
import sympy as sp
a,b = sp.symbols('a, b')
#m,n = sp.symbols('m, n')
x,t = sp.symbols('x, t')
#theta = sp.Symbol("theta")

# %%
# Differentiation - 5 Higher-Order Derivatives 
#Example 2 Page 128 - Ch2 Calculus: A Complete Course

T1 = Rational(1,3)*t**3 -3*t**2 +8*t +10
EX4 = T1.diff(t,2) # 2th Derivative
#EX4
simplify(EX4)
#factor(EX4)
# Out:
# 2*t - 6

# %%
t = 0
EX4
# Out:
# 2*(t - 3)

# %%
from sympy import symbols
from sympy.plotting import plot

p4 = plot(EX4, title="Example 4") # 2th Derivative Plot
