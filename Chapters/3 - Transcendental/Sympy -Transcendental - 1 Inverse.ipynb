# %%
# Calculcus - Sympy -Transcendental - 1 Inverse
# Page 166 - Ch3 Calculus: A Complete Course
#

from sympy import *
import sympy as sp
a,b = sp.symbols('a, b')
#m,n = sp.symbols('m, n')
x,y,t = sp.symbols('x, y, t')
#theta = sp.Symbol("theta")

# %%
# Page 166 - Ch3 Calculus: A Complete Course
HD1 = x**3

# Inverse f −1(y)
# https://en.wikipedia.org/wiki/Inverse_function

HD2 = cbrt(y) # y**1/3 - Standard inverse functions
#simplify(EX2A)

# %%
from sympy import symbols
from sympy.plotting import plot

p1 = plot(HD1, title="Y = X^3") #

# %%
from sympy import symbols
from sympy.plotting import plot

p2 = plot(HD2, title="cbrt(y)") #
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
