# %%
# Calculcus - Differentiation
# https://www.youtube.com/watch?v=BcOPKQAZcn0
# Differentiating gives the gradient of a graph

from sympy import *
x = Symbol('x')
f = exp(x)*cos(x)
derivative_f = f.diff(x)
derivative_f
# Out:
# -exp(x)*sin(x) + exp(x)*cos(x)

# %%
f = 2*x**4-6*x+1 # Q1
derivative_Q1 = f.diff(x)
derivative_Q1
# Out:
# 8*x**3 - 6

# %%
from sympy import symbols
from sympy.plotting import plot

p1 = plot(derivative_Q1, title="Plot Q1")

# %%
f = 3*x**2+((x/4)**-1)-2 #Q2
derivative_Q2 = f.diff(x)
derivative_Q2
# Out:
# 6*x - 4/x**2

# %%
from sympy import symbols
from sympy.plotting import plot

p1 = plot(derivative_Q2, title="Plot Q2")

# %%
f = 2*sqrt(x)-(5/x**2) #Q3
derivative_Q3 = f.diff(x)
derivative_Q3
# Out:
# 10/x**3 + 1/sqrt(x)

# %%
from sympy import symbols
from sympy.plotting import plot

p1 = plot(derivative_Q3, title="Plot Q3")

# %%
expand((2*x + 1)*(x - 3)) # Q4
# Out:
# 2*x**2 - 5*x - 3

# %%
f = 2*x**2-5*x-3 # (2x+1)(x-3) ^ Above
derivative_Q4 = f.diff(x)
derivative_Q4
# Out:
# 4*x - 5

# %%
from sympy import symbols
from sympy.plotting import plot

p1 = plot(derivative_Q4, title="Plot Q4")

# %%
f = (4*x**3+1)/x # Q5
derivative_Q5 = f.diff(x)
derivative_Q5
simplify(derivative_Q5)
# Out:
# 8*x - 1/x**2

# %%
from sympy import symbols
from sympy.plotting import plot

p1 = plot(derivative_Q5, title="Plot Q5")

# %%
(((2*x**3)-4)/(sqrt(x))) # Q6
# Out:
# (2*x**3 - 4)/sqrt(x)

# %%
#rom sympy import symbols
#rom sympy.plotting import plot

#1 = plot((((2*x**3)-4)/(sqrt(x))), title="Plot Q6")

# %%
simplify((((2*x**3)-4)/(sqrt(x))))
# Out:
# 2*(x**3 - 2)/sqrt(x)

# %%
#f = 2*x**-3/2-4*x**-1/2   # (2*x**3-4)/sqrt(x)
#derivative_f = f.diff(x)
#derivative_f

# %%
f = (cbrt(x**2) + x) # Q7
f
# Out:
# x + (x**2)**(1/3)

# %%
#derivative_f = f.diff(x)
#derivative_f
